# %% [markdown]
# ### View pickel DB

# %%
import sys, types, pickle
import pandas as pd

# 🧩 Create a dummy Int64Index class for backward compatibility
class Int64Index(pd.Index):
    pass

# 🧩 Fake the old pandas module path and insert our dummy class
fake_mod = types.ModuleType("pandas.core.indexes.numeric")
fake_mod.Int64Index = Int64Index
sys.modules["pandas.core.indexes.numeric"] = fake_mod

# 🗂 Load the pickle file
# with open("../data/_merged_data.pkl", "rb") as f:
with open("../data/geocat_data/geocat_metadata.pkl", "rb") as f:
    geoheravester_data = pickle.load(f)

display(geoheravester_data)
# Out:
# {'dataset':    dataset_identifier     origin xml_filename  dataset_language  \
#  0             ur-1774  geocat.ch  ur-1774.xml               NaN
#  1             ur-1775  geocat.ch  ur-1775.xml               NaN
#  2             ur-1777  geocat.ch  ur-1777.xml               NaN
#  3             ur-1784  geocat.ch  ur-1784.xml               NaN
#  4             ur-1785  geocat.ch  ur-1785.xml               NaN
#  ..                ...        ...          ...               ...
#  95            ur-2004  geocat.ch  ur-2004.xml               NaN
#  96            ur-2005  geocat.ch  ur-2005.xml               NaN
#  97            ur-2006  geocat.ch  ur-2006.xml               NaN
#  98            ur-2007  geocat.ch  ur-2007.xml               NaN
#  99            ur-2008  geocat.ch  ur-2008.xml               NaN
#
#      dataset_title_DE                              dataset_keyword_DE  \
#  0                NaN                  ['Ortsplan', 'opendata.swiss']
#  1                NaN                              ['opendata.swiss']
#  2                NaN             ['Geobasisdaten', 'opendata.swiss']
#  3                NaN             ['Geobasisdaten', 'opendata.swiss']
#  4                NaN             ['Geobasisdaten', 'opendata.swiss']
#  ..               ...                                             ...
#  95               NaN                              ['opendata.swiss']
#  96               NaN            ['Kantonsstrasse', 'opendata.swiss']
#  97               NaN            ['Kantonsstrasse', 'opendata.swiss']
#  98               NaN  ['Wegnetz', 'Geobasisdaten', 'opendata.swiss']
#  99               NaN             ['Geobasisdaten', 'opendata.swiss']
#
#      dataset_description_DE                   dataset_title_UNKNOWN  \
#  0                      NaN                                Ortsinfo
#  1                      NaN                         Lawinenkataster
#  2                      NaN  Kataster der belasteten Standorte (UR)
#  3                      NaN               Entsorgungsrouten Grüngut
#  4                      NaN              Entsorgungsrouten Kehricht
#  ..                     ...                                     ...
#  95                     NaN    Ausserorts Innerorts Kantonsstrassen
#  96                     NaN          Geschwindigkeit Kantonsstrasse
#  97                     NaN                  Tonnage Kantonsstrasse
#  98                     NaN            Velowegnetz [im Aufbau] (UR)
#  99                     NaN            Bikewegnetz [im Aufbau] (UR)
#
#                             dataset_keyword_UNKNOWN  \
#  0                   ['Ortsplan', 'opendata.swiss']
#  1                               ['opendata.swiss']
#  2              ['Geobasisdaten', 'opendata.swiss']
#  3              ['Geobasisdaten', 'opendata.swiss']
#  4              ['Geobasisdaten', 'opendata.swiss']
#  ..                                             ...
#  95                              ['opendata.swiss']
#  96            ['Kantonsstrasse', 'opendata.swiss']
#  97            ['Kantonsstrasse', 'opendata.swiss']
#  98  ['Wegnetz', 'Geobasisdaten', 'opendata.swiss']
#  99             ['Geobasisdaten', 'opendata.swiss']
#
#                            dataset_description_UNKNOWN  ...  \
#  0   Der Dateninhalt der Ortsinformationen über das...  ...
#  1   Im Lawinenkataster des Kantons Uri werden die ...  ...
#  2   Der Artikel 32c Abs. 2 USG verpflichtet die Ka...  ...
#  3   Die ZAKU sammelt im Auftrag der Gemeinden die ...  ...
#  4   Die ZAKU sammelt im Auftrag der Gemeinden den ...  ...
#  ..                                                ...  ...
#  95  Ausserorts- und Innerortsabschnitte der Kanton...  ...
#  96  Angaben der Geschwindigkeit auf der Kantonsstr...  ...
#  97       Angaben der Tonnagen auf der Kantonsstrasse.  ...
#  98  Velowegnetz des Kanton Uris. Der Datensatz bef...  ...
#  99  Bikewegnetz des Kanton Uris. Der Datensatz bef...  ...
#
#      dataset_description_length_fr dataset_description_length_it  \
#  0                             NaN                           NaN
#  1                             NaN                           NaN
#  2                             NaN                           NaN
#  3                             NaN                           NaN
#  4                             NaN                           NaN
#  ..                            ...                           ...
#  95                            NaN                           NaN
#  96                            NaN                           NaN
#  97                            NaN                           NaN
#  98                            NaN                           NaN
#  99                            NaN                           NaN
#
#      dataset_description_length_rm dataset_distribution_format_count  \
#  0                             NaN                               NaN
#  1                             NaN                               NaN
#  2                             NaN                               NaN
#  3                             NaN                               NaN
#  4                             NaN                               NaN
#  ..                            ...                               ...
#  95                            NaN                               NaN
#  96                            NaN                               NaN
#  97                            NaN                               NaN
#  98                            NaN                               NaN
#  99                            NaN                               NaN
#
#      dataset_keyword_count_de  dataset_keyword_count_en  \
#  0                        NaN                       NaN
#  1                        NaN                       NaN
#  2                        NaN                       NaN
#  3                        NaN                       NaN
#  4                        NaN                       NaN
#  ..                       ...                       ...
#  95                       NaN                       NaN
#  96                       NaN                       NaN
#  97                       NaN                       NaN
#  98                       NaN                       NaN
#  99                       NaN                       NaN
#
#      dataset_keyword_count_fr dataset_keyword_count_it  \
#  0                        NaN                      NaN
#  1                        NaN                      NaN
#  2                        NaN                      NaN
#  3                        NaN                      NaN
#  4                        NaN                      NaN
#  ..                       ...                      ...
#  95                       NaN                      NaN
#  96                       NaN                      NaN
#  97                       NaN                      NaN
#  98                       NaN                      NaN
#  99                       NaN                      NaN
#
#      dataset_keyword_count_rm  dataset_cluster_id
#  0                        NaN                 NaN
#  1                        NaN                 NaN
#  2                        NaN                 NaN
#  3                        NaN                 NaN
#  4                        NaN                 NaN
#  ..                       ...                 ...
#  95                       NaN                 NaN
#  96                       NaN                 NaN
#  97                       NaN                 NaN
#  98                       NaN                 NaN
#  99                       NaN                 NaN
#
#  [100 rows x 51 columns],
#  'distribution':     dataset_identifier           distribution_format  distribution_access_url  \
#  0              ur-1774                       OGC:WMS                      NaN
#  1              ur-1774                       OGC:WFS                      NaN
#  2              ur-1774                           NaN                      NaN
#  3              ur-1774  CHTOPO:specialised-geoportal                      NaN
#  4              ur-1775                       OGC:WMS                      NaN
#  ..                 ...                           ...                      ...
#  387            ur-2007  CHTOPO:specialised-geoportal                      NaN
#  388            ur-2008                       OGC:WMS                      NaN
#  389            ur-2008                       OGC:WFS                      NaN
#  390            ur-2008                           NaN                      NaN
#  391            ur-2008  CHTOPO:specialised-geoportal                      NaN
#
#          origin xml_filename  distribution_title_DE  \
#  0    geocat.ch  ur-1774.xml                    NaN
#  1    geocat.ch  ur-1774.xml                    NaN
#  2    geocat.ch  ur-1774.xml                    NaN
#  3    geocat.ch  ur-1774.xml                    NaN
#  4    geocat.ch  ur-1775.xml                    NaN
#  ..         ...          ...                    ...
#  387  geocat.ch  ur-2007.xml                    NaN
#  388  geocat.ch  ur-2008.xml                    NaN
#  389  geocat.ch  ur-2008.xml                    NaN
#  390  geocat.ch  ur-2008.xml                    NaN
#  391  geocat.ch  ur-2008.xml                    NaN
#
#       distribution_description_DE            distribution_title_UNKNOWN  \
#  0                            NaN  weitere:ortsinformationen_kanton_uri
#  1                            NaN                                   NaN
#  2                            NaN                                   NaN
#  3                            NaN                                GEO.UR
#  4                            NaN                    forst:lawinenkarte
#  ..                           ...                                   ...
#  387                          NaN                                GEO.UR
#  388                          NaN           strassen:ch067b_bikewegnetz
#  389                          NaN                                   NaN
#  390                          NaN                                   NaN
#  391                          NaN                                GEO.UR
#
#                        distribution_description_UNKNOWN  distribution_title_EN  \
#  0                            WMS-Dienst des Kanton Uri                    NaN
#  1                            WFS-Dienst des Kanton Uri                    NaN
#  2                                                  NaN                    NaN
#  3    Web GIS Client des Kanton Uri. Die Daten könne...                    NaN
#  4                            WMS-Dienst des Kanton Uri                    NaN
#  ..                                                 ...                    ...
#  387  Web GIS Client des Kanton Uri. Die Daten könne...                    NaN
#  388                          WMS-Dienst des Kanton Uri                    NaN
#  389                          WFS-Dienst des Kanton Uri                    NaN
#  390                                                NaN                    NaN
#  391  Web GIS Client des Kanton Uri. Die Daten könne...                    NaN
#
#       ...  distribution_description_length_en  \
#  0    ...                                 NaN
#  1    ...                                 NaN
#  2    ...                                 NaN
#  3    ...                                 NaN
#  4    ...                                 NaN
#  ..   ...                                 ...
#  387  ...                                 NaN
#  388  ...                                 NaN
#  389  ...                                 NaN
#  390  ...                                 NaN
#  391  ...                                 NaN
#
#       distribution_description_length_fr  distribution_description_length_it  \
#  0                                   NaN                                 NaN
#  1                                   NaN                                 NaN
#  2                                   NaN                                 NaN
#  3                                   NaN                                 NaN
#  4                                   NaN                                 NaN
#  ..                                  ...                                 ...
#  387                                 NaN                                 NaN
#  388                                 NaN                                 NaN
#  389                                 NaN                                 NaN
#  390                                 NaN                                 NaN
#  391                                 NaN                                 NaN
#
#       distribution_description_length_rm  distribution_format_name  \
#  0                                   NaN                       NaN
#  1                                   NaN                       NaN
#  2                                   NaN                       NaN
#  3                                   NaN                       NaN
#  4                                   NaN                       NaN
#  ..                                  ...                       ...
#  387                                 NaN                       NaN
#  388                                 NaN                       NaN
#  389                                 NaN                       NaN
#  390                                 NaN                       NaN
#  391                                 NaN                       NaN
#
#       distribution_format_type  distribution_format_cluster  \
#  0                         NaN                          NaN
#  1                         NaN                          NaN
#  2                         NaN                          NaN
#  3                         NaN                          NaN
#  4                         NaN                          NaN
#  ..                        ...                          ...
#  387                       NaN                          NaN
#  388                       NaN                          NaN
#  389                       NaN                          NaN
#  390                       NaN                          NaN
#  391                       NaN                          NaN
#
#       distribution_format_geodata  distribution_access_url_status_code  \
#  0                            NaN                                  NaN
#  1                            NaN                                  NaN
#  2                            NaN                                  NaN
#  3                            NaN                                  NaN
#  4                            NaN                                  NaN
#  ..                           ...                                  ...
#  387                          NaN                                  NaN
#  388                          NaN                                  NaN
#  389                          NaN                                  NaN
#  390                          NaN                                  NaN
#  391                          NaN                                  NaN
#
#      distribution_download_url_status_code
#  0                                     NaN
#  1                                     NaN
#  2                                     NaN
#  3                                     NaN
#  4                                     NaN
#  ..                                    ...
#  387                                   NaN
#  388                                   NaN
#  389                                   NaN
#  390                                   NaN
#  391                                   NaN
#
#  [392 rows x 46 columns],
#  'contact_point':     dataset_identifier  contact_type  contact_email  \
#  0              ur-1774           NaN            NaN
#  1              ur-1774           NaN            NaN
#  2              ur-1775           NaN            NaN
#  3              ur-1775           NaN            NaN
#  4              ur-1777           NaN            NaN
#  ..                 ...           ...            ...
#  195            ur-2006           NaN            NaN
#  196            ur-2007           NaN            NaN
#  197            ur-2007           NaN            NaN
#  198            ur-2008           NaN            NaN
#  199            ur-2008           NaN            NaN
#
#                          contact_name     origin xml_filename
#  0              Gemeinden des Kt. Uri  geocat.ch  ur-1774.xml
#  1              Gemeinden des Kt. Uri  geocat.ch  ur-1774.xml
#  2     Amt für Forst und Jagd Kt. Uri  geocat.ch  ur-1775.xml
#  3     Amt für Forst und Jagd Kt. Uri  geocat.ch  ur-1775.xml
#  4             Amt für Umwelt Kt. Uri  geocat.ch  ur-1777.xml
#  ..                               ...        ...          ...
#  195          Amt für Tiefbau Kt. Uri  geocat.ch  ur-2006.xml
#  196  Amt für Raumentwicklung Kt. Uri  geocat.ch  ur-2007.xml
#  197  Amt für Raumentwicklung Kt. Uri  geocat.ch  ur-2007.xml
#  198  Amt für Raumentwicklung Kt. Uri  geocat.ch  ur-2008.xml
#  199  Amt für Raumentwicklung Kt. Uri  geocat.ch  ur-2008.xml
#
#  [200 rows x 6 columns]}

# %%
import sys, types, pickle
import pandas as pd

# 🧩 Create a dummy Int64Index class for backward compatibility
class Int64Index(pd.Index):
    pass

# 🧩 Fake the old pandas module path and insert our dummy class
fake_mod = types.ModuleType("pandas.core.indexes.numeric")
fake_mod.Int64Index = Int64Index
sys.modules["pandas.core.indexes.numeric"] = fake_mod

# 🗂 Load the pickle file
with open("../data/geocat_data/geocat_metadata.pkl", "rb") as f:
    geoheravester_data = pickle.load(f)

# 🧭 Show the available tables (dictionary keys)
print("Available tables in pickle DB:")
for name in geoheravester_data.keys():
    print(f" - {name}")

# (optional) Display one of them, e.g. the first few rows of the dataset table
if "dataset" in geoheravester_data:
    display(geoheravester_data["dataset"])
# Out:
# Available tables in pickle DB:
#  - dataset
#  - distribution
#  - contact_point
#                                     dataset_identifier     origin  \
# 0                                    geoportal-679-103  geocat.ch
# 1                                       geoportal-68-1  geocat.ch
# 2                                      geoportal-681-1  geocat.ch
# 3                                      geoportal-681-2  geocat.ch
# 4                                      geoportal-681-3  geocat.ch
# ..                                                 ...        ...
# 995  urn:isogeo:metadata:uuid:31d848b5-6900-4e36-85...  geocat.ch
# 996  urn:isogeo:metadata:uuid:6ffd6759-eddd-4077-87...  geocat.ch
# 997  urn:isogeo:metadata:uuid:bc626451-1cd8-4fff-92...  geocat.ch
# 998  urn:isogeo:metadata:uuid:c60e44cf-94e3-4ada-bc...  geocat.ch
# 999  urn:isogeo:metadata:uuid:eb3299b7-5b0b-4308-87...  geocat.ch
#
#                                           xml_filename dataset_language  \
# 0                                geoportal-679-103.xml           ['de']
# 1                                   geoportal-68-1.xml           ['de']
# 2                                  geoportal-681-1.xml           ['de']
# 3                                  geoportal-681-2.xml           ['de']
# 4                                  geoportal-681-3.xml           ['de']
# ..                                                 ...              ...
# 995  urn_isogeo_metadata_uuid_31d848b5-6900-4e36-85...              NaN
# 996  urn_isogeo_metadata_uuid_6ffd6759-eddd-4077-87...              NaN
# 997  urn_isogeo_metadata_uuid_bc626451-1cd8-4fff-92...              NaN
# 998  urn_isogeo_metadata_uuid_c60e44cf-94e3-4ada-bc...              NaN
# 999  urn_isogeo_metadata_uuid_eb3299b7-5b0b-4308-87...              NaN
#
#                            dataset_title_de dataset_keyword_de  \
# 0                                       NaN                NaN
# 1                                       NaN                NaN
# 2                                       NaN                NaN
# 3                                       NaN                NaN
# 4                                       NaN                NaN
# ..                                      ...                ...
# 995                    Naturparks - Schweiz                NaN
# 996        Natürliche Lebensräume - Schweiz                NaN
# 997                   Wasserläufe - Schweiz                NaN
# 998  Standorte von Energiequellen - Schweiz                NaN
# 999                   Landnutzung - Schweiz                NaN
#
#                                 dataset_description_de  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  Täglicher Auszug aus den Natur-, National-, Re...
# 996  Täglicher Auszug der natürlichen Lebensräume i...
# 997  Täglicher Auszug von Wasserläufen in der Schwe...
# 998  Täglicher Auszug aus den Energiequellen der Sc...
# 999  Täglicher Auszug aus den Landnutzungsarten der...
#
#                                  dataset_title_unknown  \
# 0        Kirchberg SG - 3. Klass-Strassen und Sektoren
# 1    Kanton St.Gallen - Gewässer SG: Ökomorphologie...
# 2                Kanton St.Gallen - Oberflächenabfluss
# 3    Kanton Appenzell Ausserrhoden - Oberflächenabf...
# 4    Kanton Appenzell Innerrhoden - Oberflächenabfluss
# ..                                                 ...
# 995                            Parcs naturels - Suisse
# 996                          Milieux naturels - Suisse
# 997                               Cours d'eau - Suisse
# 998    Localisations des sources de l'énergie - Suisse
# 999                     Exploitation des sols - Suisse
#
#     dataset_keyword_unknown  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 995                     NaN
# 996                     NaN
# 997                     NaN
# 998                     NaN
# 999                     NaN
#
#                            dataset_description_unknown  ...  \
# 0    Diese Strassen dienen der Erschliessung von Si...  ...
# 1    Fliessgewässer, Ökomorphologie Stand 2013: Die...  ...
# 2    Die Gefährdungskarte Oberflächenabfluss des Bu...  ...
# 3    Die Gefährdungskarte Oberflächenabfluss des Bu...  ...
# 4    Die Gefährdungskarte Oberflächenabfluss des Bu...  ...
# ..                                                 ...  ...
# 995  Extrait quotidien des parcs naturels, nationau...  ...
# 996  Extrait quotidien des milieux naturels en Suis...  ...
# 997  Extrait quotidien des cours d'eau en Suisse pr...  ...
# 998  Extrait quotidien des sources d'énergies en Su...  ...
# 999  Extrait quotidien des types d'exploitation des...  ...
#
#     dataset_description_length_fr dataset_description_length_it  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ..                            ...                           ...
# 995                           NaN                           NaN
# 996                           NaN                           NaN
# 997                           NaN                           NaN
# 998                           NaN                           NaN
# 999                           NaN                           NaN
#
#     dataset_description_length_rm dataset_distribution_format_count  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ..                            ...                               ...
# 995                           NaN                               NaN
# 996                           NaN                               NaN
# 997                           NaN                               NaN
# 998                           NaN                               NaN
# 999                           NaN                               NaN
#
#     dataset_keyword_count_de dataset_keyword_count_en  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 995                      NaN                      NaN
# 996                      NaN                      NaN
# 997                      NaN                      NaN
# 998                      NaN                      NaN
# 999                      NaN                      NaN
#
#     dataset_keyword_count_fr dataset_keyword_count_it  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 995                      NaN                      NaN
# 996                      NaN                      NaN
# 997                      NaN                      NaN
# 998                      NaN                      NaN
# 999                      NaN                      NaN
#
#     dataset_keyword_count_rm  dataset_cluster_id
# 0                        NaN                 NaN
# 1                        NaN                 NaN
# 2                        NaN                 NaN
# 3                        NaN                 NaN
# 4                        NaN                 NaN
# ..                       ...                 ...
# 995                      NaN                 NaN
# 996                      NaN                 NaN
# 997                      NaN                 NaN
# 998                      NaN                 NaN
# 999                      NaN                 NaN
#
# [1000 rows x 51 columns]
